# %% [markdown]
# <h1 class="alert alert-success">Connect with Azure Open AI</h1>

# %%
# %pip install dotenv openai
# Out:
# /Users/naveenrai/Learning/On_Github/AI-LLM-GenAI/AI-Learning-Path/.venv/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
load_dotenv()
endpoint = os.getenv("AZURE_ENDPOINT")
model = os.getenv("AZURE_OPENAI_MODEL_NAME")

subscription_key = os.getenv("AZURE_OPENAI_API_KEY")
api_version = os.getenv("AZURE_OPENAI_API_VERSION")

# %% [markdown]
# <div class="alert alert-success">
# 1. Call to Azure OpenAI</br>
# 2. Record the time it takes.  </div>

# %%
from openai import AzureOpenAI
import time

client = AzureOpenAI(
    api_version=api_version,
    azure_endpoint=endpoint,
    api_key=subscription_key,
)

start_time = time.perf_counter()

response = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": "Explain AI in 2 sentence.",
        }
    ],
    max_completion_tokens=16384,
    model=model
)
total_time = time.perf_counter() - start_time

print(response.choices[0].message.content)
# Out:
# Artificial intelligence refers to computer systems that can perform tasks that typically require human intelligence, such as understanding language, recognizing patterns, solving problems, and learning from data. It encompasses methods like machine learning, neural networks, and natural language processing, where models improve their performance as they are exposed to more data and feedback.

# %% [markdown]
# <div class="alert alert-success"> Log the Metrics </div>

# %%
import sys, os
# Adds the current directory to the search path

from call_log import log_call
# %reload_ext autoreload

log_call(model=model, in_tokens=response.usage.prompt_tokens, out_tokens=response.usage.completion_tokens, latency_ms=total_time, tag=model)
# Out:
# 1.15e-06
# ...
# 0.00015795000000000002
